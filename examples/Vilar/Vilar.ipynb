# %%
import gillespy 
model_doc = gillespy.StochMLDocument.from_file("StochSS_model/vilar_oscillator_AIYDNg/models/data/vilar_oscillator.xml")

# %%
model = model_doc.to_model("Vilar")

# %%
model.tspan = range(1000)
res = model.run()

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plt.plot(res[0][:,0], res[0][:,1:-1])
# Out:
# [<matplotlib.lines.Line2D at 0x7f06f49c6e90>,
#  <matplotlib.lines.Line2D at 0x7f06f49c6c10>,
#  <matplotlib.lines.Line2D at 0x7f06f49c69d0>,
#  <matplotlib.lines.Line2D at 0x7f06f49c6810>,
#  <matplotlib.lines.Line2D at 0x7f06f49c6650>,
#  <matplotlib.lines.Line2D at 0x7f06f49c6490>,
#  <matplotlib.lines.Line2D at 0x7f06f49c6290>,
#  <matplotlib.lines.Line2D at 0x7f06c3b5dc50>]
